# %% [markdown]
# <a href="https://colab.research.google.com/github/prd-dahal/AI_Projects/blob/master/(scratch)Mini_Batch_Gradient_Descent_in_L_Layer_Deep_Neural_Network_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Batch Gradient Descent

# %%
#Dependencies 
import numpy as np
import matplotlib.pyplot as plt

# %%
#Main Class 

class NeuralNetwork:
  #initialize the class with hyperparameters. Here L is the depth and N is the array 
  #that contains the no of node in each Depth
  def __init__(self, alpha=0.01, epoch = 25, verbose='False', threshold=0.0001, L=2, N=[4,1],batch_size=1):
    self.alpha = alpha
    self.epoch = epoch
    self.verbose = verbose 
    self.threshold = threshold 
    self.batch_size= batch_size
    self.L = L
    self.N = N
    self.nx = 0
    self.m = 0
    self.W = {}
    self.B = {}

    #variable for forward propagation
    self.Z = {}
    self.A = {}

    #variable for backward propagation
    self.dZ = {}
    self.dW = {}
    self.dB = {}
    self.dA = {}

  def __sigmoid(self,x):
    return 1/(1+np.exp(-x))
   
  #relu activation
  def __relu(self,Z):
    return np.maximum(0,Z)
  
  #relu derivative activation
  def __reluDerivative(self,Z):
       Z[Z<=0] = 0
       Z[Z>0] = 1
       return Z
  
  #predict the value for given input x
  def predict(self,x):
    A = {}
    A[0] = x
    Z = {}
    for i in range(1,self.L+1):
        if(i<(self.L)):
          self.Z[i] = np.dot(self.W[i], A[i-1])+ self.B[i]
          self.A[i] = self.__relu(Z[i])
        else:
          self.Z[i] = np.dot(self.W[i],A[i-1])+self.B[i]
          self.A[i] = self.__sigmoid(Z[i])
    return A[self.L].mean()
  
  #initialize weights   
  def __weightInitialize(self):
    self.N.insert(0,self.nx)
    
    for i in range(1,self.L+1):
      self.W[i] = np.random.randn(self.N[i],self.N[i-1])
      self.B[i] = np.random.randn(self.N[i],1)
    
  #fit that is public which intake whole data
  def fit(self,X,y):
    self.nx = X.shape[0]
    self.__weightInitialize()
    for i in range(self.epoch):
      for i in range(1,int(X.shape[1]/self.batch_size)+1):
        self.__fitt(X[:,(i-1)*self.batch_size:i*self.batch_size], y[(i-1)*self.batch_size:i*self.batch_size])
  
  #fit each small mini batch
  def __fitt(self,X,y):
    self.nx = X.shape[0]
    self.m = X.shape[1]

    
    
    self.A[0] = X
    
   
    ##START OF FORWARD PROPAGATION
    for i in range(1,self.L+1):
      if(i<(self.L)):
        self.Z[i] = np.dot(self.W[i], self.A[i-1])+ self.B[i]
        self.A[i] = self.__relu(self.Z[i])
      else:
        self.Z[i] = np.dot(self.W[i],self.A[i-1])+self.B[i]
        self.A[i] = self.__sigmoid(self.Z[i])  
    ##END OF FORWARD PROPAGATION
      
    #ERROR CALCULATION
    j = - (y * np.log(self.A[self.L]) + (1-y) * np.log(1-self.A[self.L])) #error calculation
    J = j.mean()
    if(self.verbose==True):
      print("The error at this iteration  is {}".format(J))
    

    ##START OF BACKWARD PROPAGATION
    self.dZ[self.L] = self.A[self.L] - y
    self.dW[self.L] = (1/self.m) * np.dot(self.dZ[self.L],self.A[self.L].T)
    self.dB[self.L] = (1/self.m) * np.sum(self.dZ[self.L],axis=1,keepdims=True)
    self.dA[self.L-1] = np.dot(self.W[self.L].T, self.dZ[self.L]) 
    for i in range(self.L-1,0,-1):
      self.dZ[i] = self.dA[i] * self.__reluDerivative(self.Z[i])
      self.dW[i] = (1/self.m) * np.dot(self.dZ[i],self.A[i-1].T)
      self.dB[i] = (1/self.m) * np.sum(self.dZ[i],axis=1, keepdims=True)
      self.dA[i-1] = np.dot(self.W[i].T,self.dZ[i])
      ##END OF BACKWARD PROPAGATION

      ##WEIGHT UPDATE START
    for i in range(1,self.L+1):
      self.W[i] = self.W[i] - self.alpha * self.dW[i]
      self.B[i] = self.B[i] - self.alpha * self.dB[i]
    ## WEIGHT UPDATE ENDS     
if __name__ == '__main__':
  X = np.array([[1,2,3],
                [4,5,6],
                [8,9,10],
                [11,12,13]])
  X = X.T
  y = np.array([1,0,1,1])

  nn = NeuralNetwork(alpha=0.01, verbose=True, epoch=500, threshold = 0.4, L=3, N=[4,3,1],batch_size=X.shape[1])
  nn.fit(X,y)
# Out:
# The error at this iteration  is 4.044197488312739
# The error at this iteration  is 0.5995871877469243
# The error at this iteration  is 0.5789002524538406
# The error at this iteration  is 0.5604172324553388
# The error at this iteration  is 0.5435651027252983
# The error at this iteration  is 0.5291926062286743
# The error at this iteration  is 0.5176502562869391
# The error at this iteration  is 0.5175856979268936
# The error at this iteration  is 0.5175220057935385
# The error at this iteration  is 0.5174591314459738
# The error at this iteration  is 0.5173970290285838
# The error at this iteration  is 0.5173356551318687
# The error at this iteration  is 0.5172749686604814
# The error at this iteration  is 0.5172149307081343
# The error at this iteration  is 0.5171555044390531
# The error at this iteration  is 0.5170966549756643
# The error at this iteration  is 0.5170383492922153
# The error at this iteration  is 0.5169805561140424
# The error at this iteration  is 0.5169232458222004
# The error at this iteration  is 0.516866390363197
# The error at this iteration  is 0.5168099631635694
# The error at this iteration  is 0.5167539390490609
# The error at this iteration  is 0.5166982941681654
# The error at this iteration  is 0.5166430059198118
# The error at this iteration  is 0.5165880528849791
# The error at this iteration  is 0.5165334147620357
# The error at this iteration  is 0.5164790723056075
# The error at this iteration  is 0.5164250072687936
# The error at this iteration  is 0.5163712023485477
# The error at this iteration  is 0.5163176411340625
# The error at this iteration  is 0.5162643080579926
# The error at this iteration  is 0.5162111883503658
# The error at this iteration  is 0.5161582679950406
# The error at this iteration  is 0.5161055336885673
# The error at this iteration  is 0.5160529728013282
# The error at this iteration  is 0.5160005733408288
# The error at this iteration  is 0.5159483239170253
# The error at this iteration  is 0.5158962137095744
# The error at this iteration  is 0.5158442324369049
# The error at this iteration  is 0.5157923703270044
# The error at this iteration  is 0.5157406180898311
# The error at this iteration  is 0.5156889668912605
# The error at this iteration  is 0.5156374083284795
# The error at this iteration  is 0.5155859344067502
# The error at this iteration  is 0.5155345375174653
# The error at this iteration  is 0.5154832104174264
# The error at this iteration  is 0.5154319462092699
# The error at this iteration  is 0.5153807383229869
# The error at this iteration  is 0.5153295804984642
# The error at this iteration  is 0.5152784667689998
# The error at this iteration  is 0.5152273914457298
# The error at this iteration  is 0.5151763491029216
# The error at this iteration  is 0.5151253345640796
# The error at this iteration  is 0.5150743428888235
# The error at this iteration  is 0.515023369360488
# The error at this iteration  is 0.5149724094744129
# The error at this iteration  is 0.5149214589268745
# The error at this iteration  is 0.5148705136046292
# The error at this iteration  is 0.5148195695750336
# The error at this iteration  is 0.5147686230767051
# The error at this iteration  is 0.5147176705106967
# The error at this iteration  is 0.5146667084321538
# The error at this iteration  is 0.5146157335424283
# The error at this iteration  is 0.514564742681622
# The error at this iteration  is 0.5145137328215366
# The error at this iteration  is 0.5144627010590063
# The error at this iteration  is 0.5144116446095933
# The error at this iteration  is 0.5143605608016208
# The error at this iteration  is 0.5143094470705334
# The error at this iteration  is 0.5142583009535552
# The error at this iteration  is 0.5142071200846394
# The error at this iteration  is 0.5141559021896859
# The error at this iteration  is 0.5141046450820146
# The error at this iteration  is 0.5140533466580794
# The error at this iteration  is 0.5140020048934112
# The error at this iteration  is 0.5139506178387729
# The error at this iteration  is 0.51389918361652
# The error at this iteration  is 0.5138477004171506
# The error at this iteration  is 0.5137961664960368
# The error at this iteration  is 0.5137445801703265
# The error at this iteration  is 0.5136929398160073
# The error at this iteration  is 0.5136412438651201
# The error at this iteration  is 0.5135894908031194
# The error at this iteration  is 0.5135376791663685
# The error at this iteration  is 0.513485807539761
# The error at this iteration  is 0.5134338745544664
# The error at this iteration  is 0.5133818788857888
# The error at this iteration  is 0.5133298192511333
# The error at this iteration  is 0.5132776944080772
# The error at this iteration  is 0.5132255031525342
# The error at this iteration  is 0.5131732443170143
# The error at this iteration  is 0.5131209167689661
# The error at this iteration  is 0.5130685194092052
# The error at this iteration  is 0.513016051170415
# The error at this iteration  is 0.5129635110157268
# The error at this iteration  is 0.5129108979373631
# The error at this iteration  is 0.5128582109553513
# The error at this iteration  is 0.5128054491162962
# The error at this iteration  is 0.512752611492214
# The error at this iteration  is 0.5126996971794195
# The error at this iteration  is 0.5126467052974679
# The error at this iteration  is 0.5125936349881458
# The error at this iteration  is 0.5125404854145095
# The error at this iteration  is 0.5124872557599682
# The error at this iteration  is 0.5124339452274108
# The error at this iteration  is 0.5123805530383702
# The error at this iteration  is 0.5123270784322298
# The error at this iteration  is 0.5122735206654632
# The error at this iteration  is 0.5122198790109097
# The error at this iteration  is 0.5121661527570817
# The error at this iteration  is 0.5121123412075043
# The error at this iteration  is 0.512058443680083
# The error at this iteration  is 0.5120044595065011
# The error at this iteration  is 0.5119503880316407
# The error at this iteration  is 0.5118962286130331
# The error at this iteration  is 0.5118419806203294
# The error at this iteration  is 0.5117876434347961
# The error at this iteration  is 0.5117332164488312
# The error at this iteration  is 0.5116786990655027
# The error at this iteration  is 0.5116240906981043
# The error at this iteration  is 0.5115693907697318
# The error at this iteration  is 0.5115145987128762
# The error at this iteration  is 0.5114597139690347
# The error at this iteration  is 0.5114047359883358
# The error at this iteration  is 0.511349664229183
# The error at this iteration  is 0.5112944981579102
# The error at this iteration  is 0.5112392372484524
# The error at this iteration  is 0.5111838809820295
# The error at this iteration  is 0.5111284288468437
# The error at this iteration  is 0.5110728803377865
# The error at this iteration  is 0.5110172349561606
# The error at this iteration  is 0.5109614922094102
# The error at this iteration  is 0.5109056516108629
# The error at this iteration  is 0.5108497126794818
# The error at this iteration  is 0.510793674939627
# The error at this iteration  is 0.5107375379208264
# The error at this iteration  is 0.5106813011575545
# The error at this iteration  is 0.5106249641890214
# The error at this iteration  is 0.5105685265589675
# The error at this iteration  is 0.5105119878154682
# The error at this iteration  is 0.5104553475107444
# The error at this iteration  is 0.51039860520098
# The error at this iteration  is 0.5103417604461474
# The error at this iteration  is 0.5102848128098394
# The error at this iteration  is 0.5102277618591041
# The error at this iteration  is 0.5101706071642911
# The error at this iteration  is 0.5101133482988987
# The error at this iteration  is 0.5100559848394288
# The error at this iteration  is 0.5099985163652473
# The error at this iteration  is 0.5099409424584476
# The error at this iteration  is 0.509883262703721
# The error at this iteration  is 0.5098254766882304
# The error at this iteration  is 0.5097675840014894
# The error at this iteration  is 0.509709584235244
# The error at this iteration  is 0.509651476983361
# The error at this iteration  is 0.5095932618417172
# The error at this iteration  is 0.5095349384080954
# The error at this iteration  is 0.5094765062820817
# The error at this iteration  is 0.5094179650649673
# The error at this iteration  is 0.5093593143596543
# The error at this iteration  is 0.5093005537705627
# The error at this iteration  is 0.5092416829035421
# The error at this iteration  is 0.5091827013657875
# The error at this iteration  is 0.5091236087657538
# The error at this iteration  is 0.5090644047130781
# The error at this iteration  is 0.5090050888185014
# The error at this iteration  is 0.5089456606937929
# The error at this iteration  is 0.5088861199516794
# The error at this iteration  is 0.5088264662057731
# The error at this iteration  is 0.5087666990705064
# The error at this iteration  is 0.5087068181610638
# The error at this iteration  is 0.5086468230933202
# The error at this iteration  is 0.5085867134837785
# The error at this iteration  is 0.5085264889495108
# The error at this iteration  is 0.5084661491081007
# The error at this iteration  is 0.5084056935775871
# The error at this iteration  is 0.508345121976411
# The error at this iteration  is 0.5082844339233626
# The error at this iteration  is 0.5082236290375314
# The error at this iteration  is 0.508162706938256
# The error at this iteration  is 0.5081016672450775
# The error at this iteration  is 0.508040509577694
# The error at this iteration  is 0.5079792335559137
# The error at this iteration  is 0.5079178387996144
# The error at this iteration  is 0.5078563249286996
# The error at this iteration  is 0.5077946915630588
# The error at this iteration  is 0.5077329383225275
# The error at this iteration  is 0.5076710648268495
# The error at this iteration  is 0.5076090706956391
# The error at this iteration  is 0.5075469555483456
# The error at this iteration  is 0.5074847190042189
# The error at this iteration  is 0.5074223606822735
# The error at this iteration  is 0.5073598802012587
# The error at this iteration  is 0.5072972771796237
# The error at this iteration  is 0.5072345512354886
# The error at this iteration  is 0.5071717019866135
# The error at this iteration  is 0.5071087290503691
# The error at this iteration  is 0.5070456320437083
# The error at this iteration  is 0.5069824105831396
# The error at this iteration  is 0.5069190642846987
# The error at this iteration  is 0.5068555927639238
# The error at this iteration  is 0.5067919956358292
# The error at this iteration  is 0.5067282725148816
# The error at this iteration  is 0.5066644230149753
# The error at this iteration  is 0.5066004467494097
# The error at this iteration  is 0.5065363433308663
# The error at this iteration  is 0.5064721123713865
# The error at this iteration  is 0.5064077534823502
# The error at this iteration  is 0.5063432662744553
# The error at this iteration  is 0.5062786503576967
# The error at this iteration  is 0.5062139053413478
# The error at this iteration  is 0.5061490308339397
# The error at this iteration  is 0.5060840264432431
# The error at this iteration  is 0.5060188917762508
# The error at this iteration  is 0.5059536264391584
# The error at this iteration  is 0.5058882300373482
# The error at this iteration  is 0.5058227021753716
# The error at this iteration  is 0.5057570424569329
# The error at this iteration  is 0.5056912504848733
# The error at this iteration  is 0.5056253258611548
# The error at this iteration  is 0.5055592681868456
# The error at this iteration  is 0.5054930770621041
# The error at this iteration  is 0.5054267520861658
# The error at this iteration  is 0.5053602928573274
# The error at this iteration  is 0.5052936989729342
# The error at this iteration  is 0.5052269700293659
# The error at this iteration  is 0.505160105622024
# The error at this iteration  is 0.5050931053453172
# The error at this iteration  is 0.5050259687926512
# The error at this iteration  is 0.5049586955564138
# The error at this iteration  is 0.5048912852279648
# The error at this iteration  is 0.5048237373976229
# The error at this iteration  is 0.5047560516546543
# The error at this iteration  is 0.5046882275872621
# The error at this iteration  is 0.5046202647825742
# The error at this iteration  is 0.5045521628266325
# The error at this iteration  is 0.5044839213043835
# The error at this iteration  is 0.5044155397996657
# The error at this iteration  is 0.5043470178952013
# The error at this iteration  is 0.5042783551725853
# The error at this iteration  is 0.5042095512122755
# The error at this iteration  is 0.5041406055935832
# The error at this iteration  is 0.5040715178946631
# The error at this iteration  is 0.504002287692505
# The error at this iteration  is 0.5039329145629238
# The error at this iteration  is 0.5038633980805506
# The error at this iteration  is 0.5037937378188244
# The error at this iteration  is 0.5037239333499829
# The error at this iteration  is 0.5036539842450538
# The error at this iteration  is 0.503583890073847
# The error at this iteration  is 0.5035136504049462
# The error at this iteration  is 0.5034432648057001
# The error at this iteration  is 0.5033727328422154
# The error at this iteration  is 0.5033020540793484
# The error at this iteration  is 0.5032312280806968
# The error at this iteration  is 0.5031602544085928
# The error at this iteration  is 0.5030891326240954
# The error at this iteration  is 0.5030178622869825
# The error at this iteration  is 0.5029464429557444
# The error at this iteration  is 0.5028748741875755
# The error at this iteration  is 0.5028031555383674
# The error at this iteration  is 0.5027312865627038
# The error at this iteration  is 0.50265926681385
# The error at this iteration  is 0.5025870958437489
# The error at this iteration  is 0.5025147732030133
# The error at this iteration  is 0.5024422984409188
# The error at this iteration  is 0.5023696711053977
# The error at this iteration  is 0.502296890743032
# The error at this iteration  is 0.5022239568990473
# The error at this iteration  is 0.5021508691173063
# The error at this iteration  is 0.5020776269403021
# The error at this iteration  is 0.5020042299091525
# The error at this iteration  is 0.5019306775635931
# The error at this iteration  is 0.5018569694419719
# The error at this iteration  is 0.501783105081242
# The error at this iteration  is 0.5017090840169569
# The error at this iteration  is 0.501634905783264
# The error at this iteration  is 0.5015605699128979
# The error at this iteration  is 0.5014860759371755
# The error at this iteration  is 0.5014114233859899
# The error at this iteration  is 0.5013366117878034
# The error at this iteration  is 0.5012616406696446
# The error at this iteration  is 0.5011865095570989
# The error at this iteration  is 0.5011112179743059
# The error at this iteration  is 0.5010357654439522
# The error at this iteration  is 0.500960151487266
# The error at this iteration  is 0.5008843756240123
# The error at this iteration  is 0.5008084373724858
# The error at this iteration  is 0.5007323362495066
# The error at this iteration  is 0.5006560717704154
# The error at this iteration  is 0.5005796434490656
# The error at this iteration  is 0.5005030507978199
# The error at this iteration  is 0.5004262933275448
# The error at this iteration  is 0.5003493705476044
# The error at this iteration  is 0.5002722819658557
# The error at this iteration  is 0.5001950270886424
# The error at this iteration  is 0.5001176054207909
# The error at this iteration  is 0.500040016465604
# The error at this iteration  is 0.49996225972485614
# The error at this iteration  is 0.49988433469878796
# The error at this iteration  is 0.4998062408861014
# The error at this iteration  is 0.49972797778395417
# The error at this iteration  is 0.49964954488795443
# The error at this iteration  is 0.49957094169215616
# The error at this iteration  is 0.49949216768905375
# The error at this iteration  is 0.4994132223695767
# The error at this iteration  is 0.49933410522308525
# The error at this iteration  is 0.4992548157373637
# The error at this iteration  is 0.4991753533986176
# The error at this iteration  is 0.49909571769146666
# The error at this iteration  is 0.4990159080989407
# The error at this iteration  is 0.4989359241024749
# The error at this iteration  is 0.49885576518190305
# The error at this iteration  is 0.49877543081545506
# The error at this iteration  is 0.4986949204797501
# The error at this iteration  is 0.49861423364979207
# The error at this iteration  is 0.4985333697989651
# The error at this iteration  is 0.4984523283990279
# The error at this iteration  is 0.49837110892010933
# The error at this iteration  is 0.4982897108307027
# The error at this iteration  is 0.4982081335976618
# The error at this iteration  is 0.49812637668619564
# The error at this iteration  is 0.49804443955986255
# The error at this iteration  is 0.4979623216805667
# The error at this iteration  is 0.4978800225085524
# The error at this iteration  is 0.4977975415023994
# The error at this iteration  is 0.4977148781190176
# The error at this iteration  is 0.49763203181364246
# The error at this iteration  is 0.49754900203983066
# The error at this iteration  is 0.4974657882494538
# The error at this iteration  is 0.49738238989269506
# The error at this iteration  is 0.49729880641804286
# The error at this iteration  is 0.4972150372722873
# The error at this iteration  is 0.4971310819005146
# The error at this iteration  is 0.4970469397461021
# The error at this iteration  is 0.4969626102507138
# The error at this iteration  is 0.4968780928542952
# The error at this iteration  is 0.4967933869950688
# The error at this iteration  is 0.49670849210952867
# The error at this iteration  is 0.49662340763243595
# The error at this iteration  is 0.49653813299681443
# The error at this iteration  is 0.4964526676339445
# The error at this iteration  is 0.4963670109733596
# The error at this iteration  is 0.49628116244284093
# The error at this iteration  is 0.49619512146841194
# The error at this iteration  is 0.4961088874743346
# The error at this iteration  is 0.496022459883104
# The error at this iteration  is 0.4959358381154426
# The error at this iteration  is 0.4958490215902979
# The error at this iteration  is 0.4957620097248349
# The error at this iteration  is 0.495674801934433
# The error at this iteration  is 0.4955873976326803
# The error at this iteration  is 0.49549979623136886
# The error at this iteration  is 0.49541199714049117
# The error at this iteration  is 0.49532399976823305
# The error at this iteration  is 0.49523580352097063
# The error at this iteration  is 0.495147407803265
# The error at this iteration  is 0.49505881201785734
# The error at this iteration  is 0.49497001556566383
# The error at this iteration  is 0.4948810178457719
# The error at this iteration  is 0.4947918182554339
# The error at this iteration  is 0.4947024161900631
# The error at this iteration  is 0.49461281104322957
# The error at this iteration  is 0.4945230022066541
# The error at this iteration  is 0.49443298907020417
# The error at this iteration  is 0.49434277102188895
# The error at this iteration  is 0.49425234744785485
# The error at this iteration  is 0.49416171773237966
# The error at this iteration  is 0.4940708812578692
# The error at this iteration  is 0.49397983740485185
# The error at this iteration  is 0.4938885855519731
# The error at this iteration  is 0.4937971250759926
# The error at this iteration  is 0.4937054553517771
# The error at this iteration  is 0.49361357575229764
# The error at this iteration  is 0.4935214856486235
# The error at this iteration  is 0.4934291844099179
# The error at this iteration  is 0.4933366714034336
# The error at this iteration  is 0.49324394599450755
# The error at this iteration  is 0.4931510075465565
# The error at this iteration  is 0.49305785542107167
# The error at this iteration  is 0.492964488977615
# The error at this iteration  is 0.4928709075738138
# The error at this iteration  is 0.49277711056535545
# The error at this iteration  is 0.492683097305984
# The error at this iteration  is 0.49258886714749434
# The error at this iteration  is 0.49249441943972816
# The error at this iteration  is 0.4923997535305684
# The error at this iteration  is 0.49230486876593554
# The error at this iteration  is 0.492209764489782
# The error at this iteration  is 0.492114440044088
# The error at this iteration  is 0.4920188947688571
# The error at this iteration  is 0.49192312800211024
# The error at this iteration  is 0.4918271390798824
# The error at this iteration  is 0.4917309273362174
# The error at this iteration  is 0.4916344921031631
# The error at this iteration  is 0.49153783271076706
# The error at this iteration  is 0.49144094848707104
# The error at this iteration  is 0.49134383875810766
# The error at this iteration  is 0.49124650284789495
# The error at this iteration  is 0.4911489400784312
# The error at this iteration  is 0.4910511497696915
# The error at this iteration  is 0.49095313123962214
# The error at this iteration  is 0.49085488380413667
# The error at this iteration  is 0.4907564067771109
# The error at this iteration  is 0.4906576994703778
# The error at this iteration  is 0.49055876119372405
# The error at this iteration  is 0.4904595912548849
# The error at this iteration  is 0.4903601889595388
# The error at this iteration  is 0.4902605536113043
# The error at this iteration  is 0.4901606845117341
# The error at this iteration  is 0.4900605809603117
# The error at this iteration  is 0.48996024225444545
# The error at this iteration  is 0.48985966768946587
# The error at this iteration  is 0.4897588565586188
# The error at this iteration  is 0.4896578081530629
# The error at this iteration  is 0.4895565217618644
# The error at this iteration  is 0.48945499667199227
# The error at this iteration  is 0.4893532321683141
# The error at this iteration  is 0.4892512275335913
# The error at this iteration  is 0.4891489820484753
# The error at this iteration  is 0.48904649499150243
# The error at this iteration  is 0.48894376563908953
# The error at this iteration  is 0.4888407932655297
# The error at this iteration  is 0.4887375771429885
# The error at this iteration  is 0.4886341165414978
# The error at this iteration  is 0.48853041072895353
# The error at this iteration  is 0.4884264589711097
# The error at this iteration  is 0.48832226053157457
# The error at this iteration  is 0.48821781467180625
# The error at this iteration  is 0.4881131206511091
# The error at this iteration  is 0.48800817772662775
# The error at this iteration  is 0.4879029851533442
# The error at this iteration  is 0.48779754218407345
# The error at this iteration  is 0.487691848069458
# The error at this iteration  is 0.48758590205796526
# The error at this iteration  is 0.48747970339588226
# The error at this iteration  is 0.4873732513273111
# The error at this iteration  is 0.4872665450941658
# The error at this iteration  is 0.4871595839361678
# The error at this iteration  is 0.4870523670908409
# The error at this iteration  is 0.486944893793508
# The error at this iteration  is 0.4868371632772871
# The error at this iteration  is 0.4867291747730861
# The error at this iteration  is 0.4866209275095996
# The error at this iteration  is 0.486512420713305
# The error at this iteration  is 0.48640365360845755
# The error at this iteration  is 0.4862946254170869
# The error at this iteration  is 0.4861853353589928
# The error at this iteration  is 0.4860757826517417
# The error at this iteration  is 0.48596596651066143
# The error at this iteration  is 0.4858558861488389
# The error at this iteration  is 0.48574554077711535
# The error at this iteration  is 0.48563492960408156
# The error at this iteration  is 0.48552405183607567
# The error at this iteration  is 0.4854129066771783
# The error at this iteration  is 0.4853014933292085
# The error at this iteration  is 0.48518981099172076
# The error at this iteration  is 0.4850778588620006
# The error at this iteration  is 0.48496563613506033
# The error at this iteration  is 0.4848531420036369
# The error at this iteration  is 0.4847403756581864
# The error at this iteration  is 0.48462733628688115
# The error at this iteration  is 0.4845140230756067
# The error at this iteration  is 0.48440043520795656
# The error at this iteration  is 0.4842865718652301
# The error at this iteration  is 0.4841724322264282
# The error at this iteration  is 0.4840580154682498
# The error at this iteration  is 0.48394332076508845
# The error at this iteration  is 0.4838283472890286
# The error at this iteration  is 0.48371309420984276
# The error at this iteration  is 0.48359756069498705
# The error at this iteration  is 0.48348174590959847
# The error at this iteration  is 0.48336564901649154
# The error at this iteration  is 0.4832492691761546
# The error at this iteration  is 0.4831326055467471
# The error at this iteration  is 0.483015657284095
# The error at this iteration  is 0.4828984235416893
# The error at this iteration  is 0.48278090347068137
# The error at this iteration  is 0.4826630962198807
# The error at this iteration  is 0.4825450009357509
# The error at this iteration  is 0.4824266167624077
# The error at this iteration  is 0.4823079428416145
# The error at this iteration  is 0.48218897831278074
# The error at this iteration  is 0.4820697223129575
# The error at this iteration  is 0.48195017397683615
# The error at this iteration  is 0.4818303324367436
# The error at this iteration  is 0.48171019682264093
# The error at this iteration  is 0.48158976626211986
# The error at this iteration  is 0.4814690398803999
# The error at this iteration  is 0.4813480168003254
# The error at this iteration  is 0.48122669614236385
# The error at this iteration  is 0.48110507702460203
# The error at this iteration  is 0.48098315856274365
# The error at this iteration  is 0.4808609398701073
# The error at this iteration  is 0.48073842005762335
# The error at this iteration  is 0.4806155982338313
# The error at this iteration  is 0.48049247350487795
# The error at this iteration  is 0.48036904497451466
# The error at this iteration  is 0.4802453117440947
# The error at this iteration  is 0.48012127291257106

# %%
X = np.array([[1,2,3],
                [4,5,6],
                [8,9,10],
                [11,12,13]])
X = X.T
y = np.array([1,0,1,1])
t=(X[:,0:1])
print(y[0:2])
t.shape
# Out:
# [1 0]
# (3, 1)
